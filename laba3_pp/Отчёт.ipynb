# %% [markdown]
# ## Маясов Данила 6311  Отчет по лабораторной работе №3

# %% [markdown]
# Работа выполнена на суперкомпьютере Королев

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Полученные выводы: была сделана проверка на перемножение матриц и результаты подсчета времени выводились в консоль (это файлик interval_matrix.ipynb). Отдельно было проверено, что корректно перемножаются матрицы.
#
#
#
# По результатам моей работы были составлены графики для 1 и 16 потоков. Которые зависят от затраченного времени на перемножение 2х матриц и их размера. Также были подсчитаны доверительные интервалы (interval_matrix.ipynb):
#
# data_16 = [ [1.39231E-05, 1.27499E-05, 1.41202E-05, 1.30273E-05, 1.36150E-05, 1.36150E-05, 1.43371E-05, 1.75188E-05, 1.63638E-05, 1.43934E-05], [7.80688E-05, 0.000110084, 8.47260E-05, 0.000179691, 0.000117956, 7.45622E-05, 7.54927E-05, 9.51349E-05, 8.92882E-05, 6.46221E-05], [0.000558353, 0.000586049, 0.000703191, 0.00112558, 0.000807537, 0.000523540, 0.000686837, 0.000734897, 0.000846749, 0.000536466], [0.0666006, 0.0650546, 0.0701701, 0.0860999, 0.0802786, 0.0675335, 0.0899848, 0.0724307, 0.0806326, 0.0731515], [0.128979, 0.101282, 0.112507, 0.131999, 0.127365, 0.135262, 0.128901, 0.118309, 0.117120, 0.112928], [0.185008, 0.179937, 0.189475, 0.200827, 0.183080, 0.168495, 0.176989, 0.191851, 0.173880, 0.179517], [0.340059, 0.341440, 0.359230, 0.335316, 0.347123, 0.340187, 0.322018, 0.346858, 0.347614, 0.357041], [0.500800, 0.470354, 0.464569, 0.505646, 0.503589, 0.502187, 0.497434, 0.467351, 0.470724, 0.470296], [0.840190, 0.831094, 0.798852, 0.776276, 0.804887, 0.796584, 0.830341, 0.823394, 0.842596, 0.808059] ]
#
# Среднее значение:
# 10: 1.44*10(-5)
# 50: 9.7*10(-5)
# 100: 7.11*10(-4)
# 500: 0.0752
# 600: 0.1215
# 700: 0.1829
# 800: 0.3437
# 900: 0.4853
# 1000: 0.8152
